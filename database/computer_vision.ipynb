# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\aryajava\.vscode\database\computer_vision.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/aryajava/.vscode/database/computer_vision.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
def webcam(webcam_idx=0):
    vedio=cv2.VedioCapture(webcam_idx)
    while True:
        state,frame=vedio.read()
        if not state:
            break
        cv2.imshow('vedio output',frame)
        if cv2.waitkey(1)==27:
            break
# Out:
#   Input In [3]
#     if cv2.waitkey(1)
#                      ^
# SyntaxError: invalid syntax
